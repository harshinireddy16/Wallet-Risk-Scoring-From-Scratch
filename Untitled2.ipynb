# %%
import pandas as pd

wallets_df = pd.read_csv("Wallet id - Sheet1.csv")
wallets_df.head()
# Out:
#                                     wallet_id
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 1  0x06b51c6882b27cb05e712185531c1f74996dd988
# 2  0x0795732aacc448030ef374374eaae57d2965c16c
# 3  0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9
# 4  0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae

# %%
import requests

def fetch_compound_tx(wallet):
    url = f"https://api.covalenthq.com/v1/1/address/{wallet}/transactions_v2/"
    params = {
        'key': 'cqt_rQDBR3THGbXDWWyM3w9tXrvdthCF',  
        'page-size': 1000
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json().get("data", {}).get("items", [])
    else:
        print(f"Error for {wallet}")
        return []

# %%
def extract_features(transactions):
    if not transactions:
        return {
            'num_tx': 0,
            'total_gas': 0,
            'num_compound_interactions': 0,
            'num_failed_tx': 0
        }

    num_tx = len(transactions)
    total_gas = sum(tx.get('gas_spent', 0) for tx in transactions)
    num_failed_tx = sum(not tx.get('successful', True) for tx in transactions)
    num_compound_calls = sum('compound' in (tx.get('to_address_label') or '').lower()
                              for tx in transactions)

    return {
        'num_tx': num_tx,
        'total_gas': total_gas,
        'num_compound_interactions': num_compound_calls,
        'num_failed_tx': num_failed_tx
    }

# %%
sample_wallet = wallets_df.iloc[0, 0]
txs = fetch_compound_tx(sample_wallet)
print(f"Number of transactions fetched: {len(txs)}")
print("Sample transaction:")
print(txs[0] if txs else "No transactions found.")
# Out:
# Number of transactions fetched: 1000
# Sample transaction:
# {'block_signed_at': '2025-06-16T21:15:11Z', 'block_height': 22719696, 'block_hash': '0xff57a0c234e73c4897632e198caa0074e84d16080e0f99731a3da891faebb42b', 'tx_hash': '0x98703fb4a7c6804d82e98f009ecc0e089abd53de94696088fb9675dde740c570', 'tx_offset': 108, 'successful': True, 'miner_address': '0x95222290dd7278aa3ddd389cc1e1d165cc4bafe5', 'from_address': '0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc', 'from_address_label': None, 'to_address': '0x13173761e24c3708495b1dd314920f67f97011d0', 'to_address_label': None, 'value': '0', 'value_quote': 0.0, 'pretty_value_quote': '$0.00', 'gas_metadata': {'contract_decimals': 18, 'contract_name': 'Ether', 'contract_ticker_symbol': 'ETH', 'contract_address': '0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee', 'supports_erc': None, 'logo_url': 'https://www.datocms-assets.com/86369/1669619533-ethereum.png'}, 'gas_offered': 84929, 'gas_spent': 55815, 'gas_price': 4200000000, 'fees_paid': '234423000000000', 'gas_quote': 0.5993072070029296, 'pretty_gas_quote': '$0.60', 'gas_quote_rate': 2556.5205078125, 'log_events': [{'block_signed_at': '2025-06-16T21:15:11Z', 'block_height': 22719696, 'tx_offset': 108, 'log_offset': 369, 'tx_hash': '0x98703fb4a7c6804d82e98f009ecc0e089abd53de94696088fb9675dde740c570', 'raw_log_topics': ['0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef', '0x000000000000000000000000c6b602de080fc9ac9d96a431b2d749d38e77cbbc', '0x0000000000000000000000000039f22efb07a647557c7c5d17854cfd6d489ef3'], 'sender_contract_decimals': 9, 'sender_name': 'Free Roman Storm', 'sender_contract_ticker_symbol': 'FREEROMAN', 'sender_address': '0x13173761e24c3708495b1dd314920f67f97011d0', 'sender_address_label': None, 'sender_logo_url': 'https://logos.covalenthq.com/tokens/1/0x13173761e24c3708495b1dd314920f67f97011d0.png', 'supports_erc': ['erc20'], 'sender_factory_address': None, 'raw_log_data': '0x00000000000000000000000000000000000000000000000b671f8f0b5f8a8000', 'decoded': {'name': 'Transfer', 'signature': 'Transfer(indexed address from, indexed address to, uint256 value)', 'params': [{'name': 'from', 'type': 'address', 'indexed': True, 'decoded': True, 'value': '0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc'}, {'name': 'to', 'type': 'address', 'indexed': True, 'decoded': True, 'value': '0x0039f22efb07a647557c7c5d17854cfd6d489ef3'}, {'name': 'value', 'type': 'uint256', 'indexed': False, 'decoded': True, 'value': '210345000000000000000'}]}}]}

# %%
import time

wallet_features = []

for wallet in wallets_df.iloc[:, 0]:
    try:
        txs = fetch_compound_tx(wallet)
        features = extract_features(txs)
        features['wallet_id'] = wallet
        wallet_features.append(features)

        print(f"✅ Processed: {wallet} | {len(txs)} txns")
        time.sleep(1)  # ⏳ Delay to avoid hitting API rate limits

    except Exception as e:
        print(f"❌ Error for wallet {wallet}: {e}")

features_df = pd.DataFrame(wallet_features)
features_df.head()
# Out:
# ✅ Processed: 0x0039f22efb07a647557c7c5d17854cfd6d489ef3 | 1000 txns
# ✅ Processed: 0x06b51c6882b27cb05e712185531c1f74996dd988 | 5 txns
# ✅ Processed: 0x0795732aacc448030ef374374eaae57d2965c16c | 4 txns
# ✅ Processed: 0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9 | 80 txns
# ✅ Processed: 0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae | 5 txns
# ✅ Processed: 0x104ae61d8d487ad689969a17807ddc338b445416 | 6 txns
# ✅ Processed: 0x111c7208a7e2af345d36b6d4aace8740d61a3078 | 6 txns
# ✅ Processed: 0x124853fecb522c57d9bd5c21231058696ca6d596 | 7 txns
# ✅ Processed: 0x13b1c8b0e696aff8b4fee742119b549b605f3cbc | 4 txns
# ✅ Processed: 0x1656f1886c5ab634ac19568cd571bc72f385fdf7 | 133 txns
# ✅ Processed: 0x1724e16cb8d0e2aa4d08035bc6b5c56b680a3b22 | 6 txns
# ✅ Processed: 0x19df3e87f73c4aaf4809295561465b993e102668 | 31 txns
# ✅ Processed: 0x1ab2ccad4fc97c9968ea87d4435326715be32872 | 5 txns
# ✅ Processed: 0x1c1b30ca93ef57452d53885d97a74f61daf2bf4f | 121 txns
# ✅ Processed: 0x1e43dacdcf863676a6bec8f7d6896d6252fac669 | 3 txns
# ✅ Processed: 0x22d7510588d90ed5a87e0f838391aaafa707c34b | 76 txns
# ✅ Processed: 0x24b3460622d835c56d9a4fe352966b9bdc6c20af | 22 txns
# ✅ Processed: 0x26750f1f4277221bdb5f6991473c6ece8c821f9d | 7 txns
# ✅ Processed: 0x27f72a000d8e9f324583f3a3491ea66998275b28 | 5 txns
# ✅ Processed: 0x2844658bf341db96aa247259824f42025e3bcec2 | 4 txns
# ✅ Processed: 0x2a2fde3e1beb508fcf7c137a1d5965f13a17825e | 5 txns
# ✅ Processed: 0x330513970efd9e8dd606275fb4c50378989b3204 | 126 txns
# ✅ Processed: 0x3361bea43c2f5f963f81ac70f64e6fba1f1d2a97 | 132 txns
# ✅ Processed: 0x3867d222ba91236ad4d12c31056626f9e798629c | 4 txns
# ✅ Processed: 0x3a44be4581137019f83021eeee72b7dc57756069 | 4 txns
# ✅ Processed: 0x3e69ad05716bdc834db72c4d6d44439a7c8a902b | 5 txns
# ✅ Processed: 0x427f2ac5fdf4245e027d767e7c3ac272a1f40a65 | 204 txns
# ✅ Processed: 0x4814be124d7fe3b240eb46061f7ddfab468fe122 | 235 txns
# ✅ Processed: 0x4839e666e2baf12a51bf004392b35972eeddeabf | 20 txns
# ✅ Processed: 0x4c4d05fe859279c91b074429b5fc451182cec745 | 4 txns
# ✅ Processed: 0x4d997c89bc659a3e8452038a8101161e7e7e53a7 | 265 txns
# ✅ Processed: 0x4db0a72edb5ea6c55df929f76e7d5bb14e389860 | 5 txns
# ✅ Processed: 0x4e61251336c32e4fe6bfd5fab014846599321389 | 5 txns
# ✅ Processed: 0x4e6e724f4163b24ffc7ffe662b5f6815b18b4210 | 6 txns
# ✅ Processed: 0x507b6c0d950702f066a9a1bd5e85206f87b065ba | 43 txns
# ✅ Processed: 0x54e19653be9d4143b08994906be0e27555e8834d | 7 txns
# ✅ Processed: 0x56ba823641bfc317afc8459bf27feed6eb9ff59f | 5 txns
# ✅ Processed: 0x56cc2bffcb3f86a30c492f9d1a671a1f744d1d2f | 8 txns
# ✅ Processed: 0x578cea5f899b0dfbf05c7fbcfda1a644b2a47787 | 11 txns
# ✅ Processed: 0x58c2a9099a03750e9842d3e9a7780cdd6aa70b86 | 5 txns
# ✅ Processed: 0x58d68d4bcf9725e40353379cec92b90332561683 | 55 txns
# ✅ Processed: 0x5e324b4a564512ea7c93088dba2f8c1bf046a3eb | 4 txns
# ✅ Processed: 0x612a3500559be7be7703de6dc397afb541a16f7f | 122 txns
# ✅ Processed: 0x623af911f493747c216ad389c7805a37019c662d | 70 txns
# ✅ Processed: 0x6a2752a534faacaaa153bffbb973dd84e0e5497b | 15 txns
# ✅ Processed: 0x6d69ca3711e504658977367e13c300ab198379f1 | 5 txns
# ✅ Processed: 0x6e355417f7f56e7927d1cd971f0b5a1e6d538487 | 16 txns
# ✅ Processed: 0x70c1864282599a762c674dd9d567b37e13bce755 | 5 txns
# ✅ Processed: 0x70d8e4ab175dfe0eab4e9a7f33e0a2d19f44001e | 597 txns
# ✅ Processed: 0x7399dbeebe2f88bc6ac4e3fd7ddb836a4bce322f | 4 txns
# ✅ Processed: 0x767055590c73b7d2aaa6219da13807c493f91a20 | 4 txns
# ✅ Processed: 0x7851bdfb64bbecfb40c030d722a1f147dff5db6a | 9 txns
# ✅ Processed: 0x7b4636320daa0bc055368a4f9b9d01bd8ac51877 | 11 txns
# ✅ Processed: 0x7b57dbe2f2e4912a29754ff3e412ed9507fd8957 | 7 txns
# ✅ Processed: 0x7be3dfb5b6fcbae542ea85e76cc19916a20f6c1e | 4 txns
# ✅ Processed: 0x7de76a449cf60ea3e111ff18b28e516d89532152 | 4 txns
# ✅ Processed: 0x7e3eab408b9c76a13305ef34606f17c16f7b33cc | 15 txns
# ✅ Processed: 0x7f5e6a28afc9fb0aaf4259d4ff69991b88ebea47 | 4 txns
# ✅ Processed: 0x83ea74c67d393c6894c34c464657bda2183a2f1a | 7 txns
# ✅ Processed: 0x8441fecef5cc6f697be2c4fc4a36feacede8df67 | 24 txns
# ✅ Processed: 0x854a873b8f9bfac36a5eb9c648e285a095a7478d | 4 txns
# ✅ Processed: 0x8587d9f794f06d976c2ec1cfd523983b856f5ca9 | 5 txns
# ✅ Processed: 0x880a0af12da55df1197f41697c1a1b61670ed410 | 17 txns
# ✅ Processed: 0x8aaece100580b749a20f8ce30338c4e0770b65ed | 5 txns
# ✅ Processed: 0x8be38ea2b22b706aef313c2de81f7d179024dd30 | 33 txns
# ✅ Processed: 0x8d900f213db5205c529aaba5d10e71a0ed2646db | 15 txns
# ✅ Processed: 0x91919344c1dad09772d19ad8ad4f1bcd29c51f27 | 4 txns
# ✅ Processed: 0x93f0891bf71d8abed78e0de0885bd26355bb8b1d | 5 txns
# ✅ Processed: 0x96479b087cb8f236a5e2dcbfc50ce63b2f421da6 | 632 txns
# ✅ Processed: 0x96bb4447a02b95f1d1e85374cffd565eb22ed2f8 | 3 txns
# ✅ Processed: 0x9a363adc5d382c04d36b09158286328f75672098 | 12 txns
# ✅ Processed: 0x9ad1331c5b6c5a641acffb32719c66a80c6e1a17 | 4 txns
# ✅ Processed: 0x9ba0d85f71e145ccf15225e59631e5a883d5d74a | 60 txns
# ✅ Processed: 0x9e6ec4e98793970a1307262ba68d37594e58cd78 | 47 txns
# ✅ Processed: 0xa7e94d933eb0c439dda357f61244a485246e97b8 | 4 txns
# ✅ Processed: 0xa7f3c74f0255796fd5d3ddcf88db769f7a6bf46a | 946 txns
# ✅ Processed: 0xa98dc64bb42575efec7d1e4560c029231ce5da51 | 11 txns
# ✅ Processed: 0xb271ff7090b39028eb6e711c3f89a3453d5861ee | 8 txns
# ✅ Processed: 0xb475576594ae44e1f75f534f993cbb7673e4c8b6 | 5 txns
# ✅ Processed: 0xb57297c5d02def954794e593db93d0a302e43e5c | 11 txns
# ✅ Processed: 0xbd4a00764217c13a246f86db58d74541a0c3972a | 580 txns
# ✅ Processed: 0xc179d55f7e00e789915760f7d260a1bf6285278b | 12 txns
# ✅ Processed: 0xc22b8e78394ce52e0034609a67ae3c959daa84bc | 95 txns
# ✅ Processed: 0xcbbd9fe837a14258286bbf2e182cbc4e4518c5a3 | 140 txns
# ✅ Processed: 0xcecf5163bb057c1aff4963d9b9a7d2f0bf591710 | 5 txns
# ✅ Processed: 0xcf0033bf27804640e5339e06443e208db5870dd2 | 5 txns
# ✅ Processed: 0xd0df53e296c1e3115fccc3d7cdf4ba495e593b56 | 6 txns
# ✅ Processed: 0xd1a3888fd8f490367c6104e10b4154427c02dd9c | 5 txns
# ✅ Processed: 0xd334d18fa6bada9a10f361bae42a019ce88a3c33 | 6 txns
# ✅ Processed: 0xd9d3930ffa343f5a0eec7606d045d0843d3a02b4 | 8 txns
# ✅ Processed: 0xdde73df7bd4d704a89ad8421402701b3a460c6e9 | 107 txns
# ✅ Processed: 0xde92d70253604fd8c5998c8ee3ed282a41b33b7f | 4 txns
# ✅ Processed: 0xded1f838ae6aa5fcd0f13481b37ee88e5bdccb3d | 12 txns
# ✅ Processed: 0xebb8629e8a3ec86cf90cb7600264415640834483 | 8 txns
# ✅ Processed: 0xeded1c8c0a0c532195b8432153f3bfa81dba2a90 | 5 txns
# ✅ Processed: 0xf10fd8921019615a856c1e95c7cd3632de34edc4 | 76 txns
# ✅ Processed: 0xf340b9f2098f80b86fbc5ede586c319473aa11f3 | 701 txns
# ✅ Processed: 0xf54f36bca969800fd7d63a68029561309938c09b | 4 txns
# ✅ Processed: 0xf60304b534f74977e159b2e159e135475c245526 | 18 txns
# ✅ Processed: 0xf67e8e5805835465f7eba988259db882ab726800 | 4 txns
# ✅ Processed: 0xf7aa5d0752cfcd41b0a5945867d619a80c405e52 | 4 txns
# ✅ Processed: 0xf80a8b9cfff0febf49914c269fb8aead4a22f847 | 13 txns
# ✅ Processed: 0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac | 4 txns
#    num_tx  total_gas  num_compound_interactions  num_failed_tx  \
# 0    1000  561079655                          0             13
# 1       5     308732                          0              0
# 2       4     290793                          0              0
# 3      80  132280277                          0              0
# 4       5     308720                          0              0
#
#                                     wallet_id
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 1  0x06b51c6882b27cb05e712185531c1f74996dd988
# 2  0x0795732aacc448030ef374374eaae57d2965c16c
# 3  0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9
# 4  0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae

# %%
from sklearn.preprocessing import MinMaxScaler


scoring_cols = ['num_tx', 'total_gas', 'num_compound_interactions', 'num_failed_tx']


features_df[scoring_cols] = features_df[scoring_cols].fillna(0)


scaler = MinMaxScaler()
normalized = scaler.fit_transform(features_df[scoring_cols])

weights = {
    'num_tx': 0.25,
    'total_gas': 0.25,
    'num_compound_interactions': 0.3,
    'num_failed_tx': -0.2
}


weighted_scores = (
    normalized[:, 0] * weights['num_tx'] +
    normalized[:, 1] * weights['total_gas'] +
    normalized[:, 2] * weights['num_compound_interactions'] +
    normalized[:, 3] * weights['num_failed_tx']
)


features_df['score'] = (weighted_scores - weighted_scores.min()) / (weighted_scores.max() - weighted_scores.min()) * 1000
features_df['score'] = features_df['score'].round(0).astype(int)


features_df[['wallet_id', 'score']].head()
# Out:
#                                     wallet_id  score
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3    691
# 1  0x06b51c6882b27cb05e712185531c1f74996dd988    240
# 2  0x0795732aacc448030ef374374eaae57d2965c16c    239
# 3  0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9    313
# 4  0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae    240

# %%
features_df[['wallet_id', 'score']].to_csv("wallet_scores.csv", index=False)
print("✅ Risk scores saved to wallet_scores.csv")
# Out:
# ✅ Risk scores saved to wallet_scores.csv
